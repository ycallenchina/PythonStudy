# %%
import numpy as np
import pandas as pd

a=open(r'C:\Users\YcAllenEffy\Desktop\css学习.txt',encoding='utf-8')
b=a.readlines()

k=3
j=0
time_list=[]
for i in b:
    j+=1
    if j-k==0:
        time_list.append(i[:-1])
#         print(i)
        j=0
time_list
# Out:
# ['04:30',
#  '03:55',
#  '00:39',
#  '07:40',
#  '04:44',
#  '07:33',
#  '01:06',
#  '07:12',
#  '07:20',
#  '06:37',
#  '08:33',
#  '09:00',
#  '02:22',
#  '05:15',
#  '06:24',
#  '04:27',
#  '07:45',
#  '04:44',
#  '09:13',
#  '04:15',
#  '02:43',
#  '06:35',
#  '06:11',
#  '02:57',
#  '03:21',
#  '08:39',
#  '09:16',
#  '07:08',
#  '08:19',
#  '10:37',
#  '05:14',
#  '01:12',
#  '08:11',
#  '02:32',
#  '08:25',
#  '09:26',
#  '04:46',
#  '08:30',
#  '03:45',
#  '08:48',
#  '03:21',
#  '06:42',
#  '02:55',
#  '04:21',
#  '05:27',
#  '06:20',
#  '04:37',
#  '05:53',
#  '03:35',
#  '03:04',
#  '06:32',
#  '04:15',
#  '06:11',
#  '05:42',
#  '05:14',
#  '08:23',
#  '08:59',
#  '05:24',
#  '04:05',
#  '06:15',
#  '01:10',
#  '05:10',
#  '07:18',
#  '04:43',
#  '03:30',
#  '06:02',
#  '10:31',
#  '05:22',
#  '08:03',
#  '06:20',
#  '05:10',
#  '07:36',
#  '04:02',
#  '08:08',
#  '03:10',
#  '07:34',
#  '03:04',
#  '05:56',
#  '03:06',
#  '05:05',
#  '05:28',
#  '08:11',
#  '02:59',
# ...

# %%
timelist=[pd.Timedelta('00:'+i) for i in time_list]
timelist
# Out:
# [Timedelta('0 days 00:04:30'),
#  Timedelta('0 days 00:03:55'),
#  Timedelta('0 days 00:00:39'),
#  Timedelta('0 days 00:07:40'),
#  Timedelta('0 days 00:04:44'),
#  Timedelta('0 days 00:07:33'),
#  Timedelta('0 days 00:01:06'),
#  Timedelta('0 days 00:07:12'),
#  Timedelta('0 days 00:07:20'),
#  Timedelta('0 days 00:06:37'),
#  Timedelta('0 days 00:08:33'),
#  Timedelta('0 days 00:09:00'),
#  Timedelta('0 days 00:02:22'),
#  Timedelta('0 days 00:05:15'),
#  Timedelta('0 days 00:06:24'),
#  Timedelta('0 days 00:04:27'),
#  Timedelta('0 days 00:07:45'),
#  Timedelta('0 days 00:04:44'),
#  Timedelta('0 days 00:09:13'),
#  Timedelta('0 days 00:04:15'),
#  Timedelta('0 days 00:02:43'),
#  Timedelta('0 days 00:06:35'),
#  Timedelta('0 days 00:06:11'),
#  Timedelta('0 days 00:02:57'),
#  Timedelta('0 days 00:03:21'),
#  Timedelta('0 days 00:08:39'),
#  Timedelta('0 days 00:09:16'),
#  Timedelta('0 days 00:07:08'),
#  Timedelta('0 days 00:08:19'),
#  Timedelta('0 days 00:10:37'),
# ...

# %%
a=pd.Timedelta('0')

for i in timelist:
    a+=i
a
# Out:
# Timedelta('2 days 08:10:54')
