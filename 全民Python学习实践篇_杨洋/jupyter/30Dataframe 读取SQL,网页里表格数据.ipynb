# %% [markdown]
# ### import pymysql
#
# import sqlalchemy as sac
#
#
#
# #### Sql代理
#
#   engine=sac.create_engine('驱动字符串')
#
#   驱动字符串结构解析:
#
# |'mysql|+pymysql|://root:123456|@localhost:3306|/test_data'|
# |-|-|-|-|-|
# |数据库|数据库驱动|用户名及密码|本机及端口|数据库文件名|
#
#
# |'sqlite:///|文件路径'|
# |-|-|
# |sqlite为python自带数据库|此写法为sqlite写法|
#
#
#   读取数据库
#
#     df=pd.read_sql_query('sql语句',engine)
#
#   写入数据库
#
#     pd.to_sql('sql语句',engine)
#
#
#
# #### Excel写入
#
#   df.to_excel('保存路径') 参数sheet_name='表名'
#
#
#
#   df添加到excel数据方法
#
#     writer=pd.ExcleWriter('excel路径',mode='a',engine='openpyxl')
#
#       #a表示保留原有数据,换成w表示覆盖原有数据
#
#       #openpyxl为excel驱动
#
#     df.to_excel(writer,sheet_name='新表名')
#
#     writer.save()#必需写
#
#     writer.close()#必需写
#
#
#
# #### 网页数据写入
#
#   df.to_html('保存路径')
#
#
#
#   df读取网页数据
#
#     df=pd.read_html('网址')
#
#     注意:http:
#
#     结果返回为:一个列表,里面包含所有网页里的表格,可用df[0]切片取出df
