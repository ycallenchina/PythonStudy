# %% [markdown]
# ### 读取 read_excel 方式(read_csv 和read_table"txt"同理)

# %% [markdown]
# ###  选取读取模块 openpyxl,防止误读

# %%
import pandas as pd
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13try.xlsx',engine='openpyxl')
df
# Out:
#            date       code               time  open  close    new   ma5
# 0    2021-01-08  sz.000778  20210108093500000  3.73   3.72  14.83  3.71
# 1    2021-01-08  sz.000778  20210108094000000  3.72   3.72  14.83  3.71
# 2    2021-01-08  sz.000778  20210108094500000  3.72   3.69  14.83  3.70
# 3    2021-01-08  sz.000778  20210108095000000  3.70   3.70  14.83  3.71
# 4    2021-01-08  sz.000778  20210108095500000  3.70   3.70  14.83  3.71
# ...         ...        ...                ...   ...    ...    ...   ...
# 1627 2021-03-03  sz.000778  20210303144000000  3.88   3.88  15.02  3.78
# 1628 2021-03-03  sz.000778  20210303144500000  3.88   3.87  15.02  3.78
# 1629 2021-03-03  sz.000778  20210303145000000  3.88   3.87  15.02  3.78
# 1630 2021-03-03  sz.000778  20210303145500000  3.87   3.88  15.02  3.78
# 1631 2021-03-03  sz.000778  20210303150000000  3.88   3.88  15.02  3.78
#
# [1632 rows x 7 columns]

# %% [markdown]
# ### 指定第2张工作表 (读取第二张)

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13try.xlsx',engine='openpyxl',sheet_name=1)
df
# Out:
#   表头1 表头2
# 0   a   b

# %% [markdown]
# ###  读取指定名称工作表

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13try.xlsx',engine='openpyxl',sheet_name='第二张表')
df
# Out:
#   表头1 表头2
# 0   a   b

# %% [markdown]
# ### 同时读取 几张表

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13try.xlsx',engine='openpyxl',sheet_name=[0,1])

df
# Out:
# {0:            date       code               time  open  close    new   ma5
#  0    2021-01-08  sz.000778  20210108093500000  3.73   3.72  14.83  3.71
#  1    2021-01-08  sz.000778  20210108094000000  3.72   3.72  14.83  3.71
#  2    2021-01-08  sz.000778  20210108094500000  3.72   3.69  14.83  3.70
#  3    2021-01-08  sz.000778  20210108095000000  3.70   3.70  14.83  3.71
#  4    2021-01-08  sz.000778  20210108095500000  3.70   3.70  14.83  3.71
#  ...         ...        ...                ...   ...    ...    ...   ...
#  1627 2021-03-03  sz.000778  20210303144000000  3.88   3.88  15.02  3.78
#  1628 2021-03-03  sz.000778  20210303144500000  3.88   3.87  15.02  3.78
#  1629 2021-03-03  sz.000778  20210303145000000  3.88   3.87  15.02  3.78
#  1630 2021-03-03  sz.000778  20210303145500000  3.87   3.88  15.02  3.78
#  1631 2021-03-03  sz.000778  20210303150000000  3.88   3.88  15.02  3.78
#
#  [1632 rows x 7 columns],
#  1:   表头1 表头2
#  0   a   b}

# %% [markdown]
# ### 同时读取表时,其中 df 是一个字典

# %%
df[0]
# Out:
#            date       code               time  open  close    new   ma5
# 0    2021-01-08  sz.000778  20210108093500000  3.73   3.72  14.83  3.71
# 1    2021-01-08  sz.000778  20210108094000000  3.72   3.72  14.83  3.71
# 2    2021-01-08  sz.000778  20210108094500000  3.72   3.69  14.83  3.70
# 3    2021-01-08  sz.000778  20210108095000000  3.70   3.70  14.83  3.71
# 4    2021-01-08  sz.000778  20210108095500000  3.70   3.70  14.83  3.71
# ...         ...        ...                ...   ...    ...    ...   ...
# 1627 2021-03-03  sz.000778  20210303144000000  3.88   3.88  15.02  3.78
# 1628 2021-03-03  sz.000778  20210303144500000  3.88   3.87  15.02  3.78
# 1629 2021-03-03  sz.000778  20210303145000000  3.88   3.87  15.02  3.78
# 1630 2021-03-03  sz.000778  20210303145500000  3.87   3.88  15.02  3.78
# 1631 2021-03-03  sz.000778  20210303150000000  3.88   3.88  15.02  3.78
#
# [1632 rows x 7 columns]

# %%
df[1]
# Out:
#   表头1 表头2
# 0   a   b

# %% [markdown]
# ###  缺失表头

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13缺失表头try.xlsx',engine='openpyxl',sheet_name=[0,1])

df
# Out:
# {0:                Unnamed: 0 Unnamed: 1         Unnamed: 2 Unnamed: 3 Unnamed: 4  \
#  0                     NaN        NaN                NaN        NaN        NaN
#  1                     NaN        NaN                NaN        NaN        NaN
#  2                    date       code               time       open      close
#  3     2021-01-08 00:00:00  sz.000778  20210108093500000       3.73       3.72
#  4     2021-01-08 00:00:00  sz.000778  20210108094000000       3.72       3.72
#  ...                   ...        ...                ...        ...        ...
#  1630  2021-03-03 00:00:00  sz.000778  20210303144000000       3.88       3.88
#  1631  2021-03-03 00:00:00  sz.000778  20210303144500000       3.88       3.87
#  1632  2021-03-03 00:00:00  sz.000778  20210303145000000       3.88       3.87
#  1633  2021-03-03 00:00:00  sz.000778  20210303145500000       3.87       3.88
#  1634  2021-03-03 00:00:00  sz.000778  20210303150000000       3.88       3.88
#
# ...

# %% [markdown]
# ### 处理缺失表头,指定表头位置

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13缺失表头try.xlsx',engine='openpyxl',header=3)#表头在第4行

df
# Out:
#            date       code               time  open  close    new   ma5
# 0    2021-01-08  sz.000778  20210108093500000  3.73   3.72  14.83  3.71
# 1    2021-01-08  sz.000778  20210108094000000  3.72   3.72  14.83  3.71
# 2    2021-01-08  sz.000778  20210108094500000  3.72   3.69  14.83  3.70
# 3    2021-01-08  sz.000778  20210108095000000  3.70   3.70  14.83  3.71
# 4    2021-01-08  sz.000778  20210108095500000  3.70   3.70  14.83  3.71
# ...         ...        ...                ...   ...    ...    ...   ...
# 1627 2021-03-03  sz.000778  20210303144000000  3.88   3.88  15.02  3.78
# 1628 2021-03-03  sz.000778  20210303144500000  3.88   3.87  15.02  3.78
# 1629 2021-03-03  sz.000778  20210303145000000  3.88   3.87  15.02  3.78
# 1630 2021-03-03  sz.000778  20210303145500000  3.87   3.88  15.02  3.78
# 1631 2021-03-03  sz.000778  20210303150000000  3.88   3.88  15.02  3.78
#
# [1632 rows x 7 columns]

# %% [markdown]
# ### 指定多行表头

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13缺失表头try.xlsx',engine='openpyxl',header=[3,4])#表头在第4行

df
# Out:
#                     date       code               time  open close    new  \
#      2021-01-08 00:00:00  sz.000778  20210108093500000  3.73  3.72  14.83
# 0             2021-01-08  sz.000778  20210108094000000  3.72  3.72  14.83
# 1             2021-01-08  sz.000778  20210108094500000  3.72  3.69  14.83
# 2             2021-01-08  sz.000778  20210108095000000  3.70  3.70  14.83
# 3             2021-01-08  sz.000778  20210108095500000  3.70  3.70  14.83
# 4             2021-01-08  sz.000778  20210108100000000  3.70  3.73  14.83
# ...                  ...        ...                ...   ...   ...    ...
# 1626          2021-03-03  sz.000778  20210303144000000  3.88  3.88  15.02
# 1627          2021-03-03  sz.000778  20210303144500000  3.88  3.87  15.02
# 1628          2021-03-03  sz.000778  20210303145000000  3.88  3.87  15.02
# 1629          2021-03-03  sz.000778  20210303145500000  3.87  3.88  15.02
# 1630          2021-03-03  sz.000778  20210303150000000  3.88  3.88  15.02
#
# ...

# %% [markdown]
# ### 无表头

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13缺失表头try.xlsx',engine='openpyxl',header=None)#表头在第4行

df
# Out:
#                         0          1                  2     3      4      5  \
# 0                     NaN        NaN                NaN   NaN    NaN    NaN
# 1                     NaN        NaN                NaN   NaN    NaN    NaN
# 2                     NaN        NaN                NaN   NaN    NaN    NaN
# 3                    date       code               time  open  close    new
# 4     2021-01-08 00:00:00  sz.000778  20210108093500000  3.73   3.72  14.83
# ...                   ...        ...                ...   ...    ...    ...
# 1631  2021-03-03 00:00:00  sz.000778  20210303144000000  3.88   3.88  15.02
# 1632  2021-03-03 00:00:00  sz.000778  20210303144500000  3.88   3.87  15.02
# 1633  2021-03-03 00:00:00  sz.000778  20210303145000000  3.88   3.87  15.02
# 1634  2021-03-03 00:00:00  sz.000778  20210303145500000  3.87   3.88  15.02
# 1635  2021-03-03 00:00:00  sz.000778  20210303150000000  3.88   3.88  15.02
#
#          6
# 0      NaN
# 1      NaN
# 2      NaN
# ...

# %% [markdown]
# ### 新表头 自建表头

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13缺失表头try.xlsx',engine='openpyxl',sheet_name='第二张表',header=None,names=['新表头1','新表头2'])#表头在第4行

df
# Out:
#   新表头1 新表头2
# 0  表头1  表头2
# 1    a    b

# %% [markdown]
# ### 缺失列

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13缺失列try.xlsx',engine='openpyxl',header=3)

df
# Out:
#       Unnamed: 0  Unnamed: 1       date       code               time  open  \
# 0            NaN         NaN 2021-01-08  sz.000778  20210108093500000  3.73
# 1            NaN         NaN 2021-01-08  sz.000778  20210108094000000  3.72
# 2            NaN         NaN 2021-01-08  sz.000778  20210108094500000  3.72
# 3            NaN         NaN 2021-01-08  sz.000778  20210108095000000  3.70
# 4            NaN         NaN 2021-01-08  sz.000778  20210108095500000  3.70
# ...          ...         ...        ...        ...                ...   ...
# 1627         NaN         NaN 2021-03-03  sz.000778  20210303144000000  3.88
# 1628         NaN         NaN 2021-03-03  sz.000778  20210303144500000  3.88
# 1629         NaN         NaN 2021-03-03  sz.000778  20210303145000000  3.88
# 1630         NaN         NaN 2021-03-03  sz.000778  20210303145500000  3.87
# 1631         NaN         NaN 2021-03-03  sz.000778  20210303150000000  3.88
#
#       close    new   ma5
# 0      3.72  14.83  3.71
# ...

# %% [markdown]
# ### 解决缺失列  只取c到i列

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13缺失列try.xlsx',engine='openpyxl',header=3,usecols="C:I")

df
# Out:
#            date       code               time  open  close    new   ma5
# 0    2021-01-08  sz.000778  20210108093500000  3.73   3.72  14.83  3.71
# 1    2021-01-08  sz.000778  20210108094000000  3.72   3.72  14.83  3.71
# 2    2021-01-08  sz.000778  20210108094500000  3.72   3.69  14.83  3.70
# 3    2021-01-08  sz.000778  20210108095000000  3.70   3.70  14.83  3.71
# 4    2021-01-08  sz.000778  20210108095500000  3.70   3.70  14.83  3.71
# ...         ...        ...                ...   ...    ...    ...   ...
# 1627 2021-03-03  sz.000778  20210303144000000  3.88   3.88  15.02  3.78
# 1628 2021-03-03  sz.000778  20210303144500000  3.88   3.87  15.02  3.78
# 1629 2021-03-03  sz.000778  20210303145000000  3.88   3.87  15.02  3.78
# 1630 2021-03-03  sz.000778  20210303145500000  3.87   3.88  15.02  3.78
# 1631 2021-03-03  sz.000778  20210303150000000  3.88   3.88  15.02  3.78
#
# [1632 rows x 7 columns]

# %% [markdown]
# ###  指定索引列 index_col

# %% [markdown]
# ### 跳过前几行  skiprows

# %%
df=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\13缺失列try.xlsx',engine='openpyxl',header=3,usecols="C:I",skiprows=[1,2])
df
# Out:
#      2021-01-08 00:00:00  sz.000778  20210108094000000  3.72  3.72.1  14.83  \
# 0             2021-01-08  sz.000778  20210108094500000  3.72    3.69  14.83
# 1             2021-01-08  sz.000778  20210108095000000  3.70    3.70  14.83
# 2             2021-01-08  sz.000778  20210108095500000  3.70    3.70  14.83
# 3             2021-01-08  sz.000778  20210108100000000  3.70    3.73  14.83
# 4             2021-01-08  sz.000778  20210108100500000  3.72    3.73  14.83
# ...                  ...        ...                ...   ...     ...    ...
# 1625          2021-03-03  sz.000778  20210303144000000  3.88    3.88  15.02
# 1626          2021-03-03  sz.000778  20210303144500000  3.88    3.87  15.02
# 1627          2021-03-03  sz.000778  20210303145000000  3.88    3.87  15.02
# 1628          2021-03-03  sz.000778  20210303145500000  3.87    3.88  15.02
# 1629          2021-03-03  sz.000778  20210303150000000  3.88    3.88  15.02
#
#       3.71
# 0     3.70
# 1     3.71
# 2     3.71
# ...

# %% [markdown]
# ### 跳过偶数行 skiprows
