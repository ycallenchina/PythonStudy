# %% [markdown]
# ###    下载并读取空气监测数据，完成以下需求：
#
#     1. 创建分类绘图，展示各监测点的平均污染指数，根据指数级别分类绘制柱形图；
#
#     2. 将x轴标签旋转30度，右对齐，隐藏误差线。

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
sh=pd.read_excel(r'C:\Users\YcAllenEffy\Desktop\空气监测.xlsx')
df=sh

# %%
df
# Out:
#                                        序号  污染指数  监测点         时间 指数级别 指数类别  \
# 0    00f60ce3-db7c-414e-80e0-8b24611e747d    39  华侨城 2019-02-14   一级    优
# 1    00ffda7b-8094-464c-ae73-9659db468def    88   葵涌 2017-03-28   二级    良
# 2    0100f95a-f6dd-44cf-a1b8-91e65cadf62d    50   盐田 2017-02-06   一级    优
# 3    0111a697-b8d4-453d-bbe0-b280069e5d51    42   葵涌 2019-04-14   一级    优
# 4    0111eae0-d8df-4573-aed9-0be536ad69ed    79   观澜 2015-02-18   二级    良
# ..                                    ...   ...  ...        ...  ...  ...
# 185  1a258a94-0522-4a26-b6c9-bbc8b7f892f1    30   西乡 2019-06-29   一级    优
# 186  1a3b705f-1839-423f-befd-edec44304353    89   洪湖 2016-09-18   二级    良
# 187  1a3c9b0e-2d31-4775-bd78-aac760162d4e    87   南油 2016-04-13   二级    良
# 188  1a3e909c-fef7-41ee-962b-55d23a1c527f    42   盐田 2016-10-19   一级    优
# 189  1a443285-af1a-4c73-9895-8495ed0137eb    49   洪湖 2016-09-29   一级    优
#
#     指数颜色 首要污染物                             健康影响状况
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
#设置画图 中文字体初始化
sns.set_style('whitegrid', {'font.sans-serif':['simhei', 'Arial']})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   序号      190 non-null    object
#  1   污染指数    190 non-null    int64
#  2   监测点     190 non-null    object
#  3   时间      190 non-null    datetime64[ns]
#  4   指数级别    190 non-null    object
#  5   指数类别    190 non-null    object
#  6   指数颜色    190 non-null    object
#  7   首要污染物   190 non-null    object
#  8   健康影响状况  190 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 13.5+ KB

# %%
ga=sns.catplot(data=df,x='监测点',y='污染指数',kind='bar',col='指数级别',estimator=np.mean,ci=None)


for g in ga.axes.flat:
    
#     g.figure.set_size_inches(15,5)
#     g.figure.canvas.draw() #画图
    g.set_xticklabels(labels=g.get_xticklabels(),rotation=30,size='x-large',horizontalalignment='right')#x轴标签字体设置large 大号
    g.set_yticklabels(labels=g.get_yticklabels(), size='xx-large');#y轴标签字体设置为x-large 加大号

# %%
# 标准答案
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid', {'font.sans-serif':['simhei', 'Arial']})

# df = pd.read_excel(r'.\空气监测.xlsx')
g = sns.catplot(data=df, x='监测点', y='污染指数', col='指数级别', kind='bar', ci=None)
for f in g.axes.flat:
        f.set_xticklabels(f.get_xticklabels(), rotation=30, horizontalalignment='right')

# %% [markdown]
# ###     下载并读取空气监测数据，完成以下需求：
#
#     1. 创建分类绘图，展示各监测点的平均污染指数，根据指数级别分类绘制柱形图，将多个柱形图绘制到同一个图表中；
#
#     2. 将x轴标签旋转30度，右对齐，隐藏误差线。

# %%
ga=sns.catplot(data=df,x='监测点',y='污染指数',kind='bar',hue='指数级别',estimator=np.mean,ci=None)


for g in ga.axes.flat:
    print(type(g))
#     g.figure.set_size_inches(15,5)
#     g.figure.canvas.draw() #画图
    g.set_xticklabels(labels=g.get_xticklabels(),rotation=30,size='x-large',horizontalalignment='right')#x轴标签字体设置large 大号
    g.set_yticklabels(labels=g.get_yticklabels(), size='xx-large');#y轴标签字体设置为x-large 加大号
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
# 标准答案
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid', {'font.sans-serif':['simhei', 'Arial']})

# df = pd.read_excel(r'.\空气监测.xlsx')

g = sns.catplot(data=df, x='监测点', y='污染指数', kind='bar', ci=None, hue='指数级别')
for f in g.axes.flat:
        f.set_xticklabels(f.get_xticklabels(), rotation=30, horizontalalignment='right')

# %% [markdown]
# ### 下载并读取空气监测数据，完成以下需求：
#
#     1. 创建透视表，行为监测点，列为指数级别，统计平均污染指数；
#
#     2. 根据透视表创建堆叠柱形图，展示各监测点的污染指数情况；
#
#     3. 将x轴标签旋转30度，右对齐。

# %%
df_cat=pd.pivot_table(df,index='监测点',columns='指数级别',values='污染指数',aggfunc='mean')

# %%
g=df_cat.plot(kind='bar',stacked=True)
g.set_xticklabels(g.get_xticklabels(), rotation=30, horizontalalignment='right')
# Out:
# [Text(0, 0, '华侨城'),
#  Text(0, 0, '南油'),
#  Text(0, 0, '南海'),
#  Text(0, 0, '南澳'),
#  Text(0, 0, '梅沙'),
#  Text(0, 0, '洪湖'),
#  Text(0, 0, '盐田'),
#  Text(0, 0, '荔园'),
#  Text(0, 0, '葵涌'),
#  Text(0, 0, '西乡'),
#  Text(0, 0, '观澜'),
#  Text(0, 0, '通心岭'),
#  Text(0, 0, '龙岗')]

# %%
# 标准答案
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid', {'font.sans-serif':['simhei', 'Arial']})

# df = pd.read_excel(r'.\空气监测.xlsx')

df_cat = pd.pivot_table(df, index=['监测点'], columns=['指数级别'], values='污染指数', aggfunc='mean')
g = df_cat.plot(kind='bar', stacked=True, alpha=0.6)
g.set_xticklabels(f.get_xticklabels(), rotation=30,             
                    horizontalalignment='right');

# %%
import pygal
from pygal.style import Style

# %%
# df_cat2=pd.pivot_table(df,index='监测点',columns='指数级别',values='污染指数',aggfunc='sum')
df_cat2 = pd.pivot_table(df, index=['监测点'], columns=['指数级别'], 
                            values='污染指数', aggfunc='sum')
df_cat2
# Out:
# 指数级别     一级     三级      二级     四级
# 监测点
# 华侨城   216.0    NaN   493.0    NaN
# 南油    173.0    NaN   347.0    NaN
# 南海      NaN  120.0   211.0    NaN
# 南澳    164.0    NaN   318.0    NaN
# 梅沙    387.0    NaN   329.0    NaN
# 洪湖    268.0    NaN   834.0  166.0
# 盐田    586.0  110.0   499.0    NaN
# 荔园     84.0    NaN   356.0    NaN
# 葵涌    427.0  108.0   521.0  155.0
# 西乡    268.0  679.0   729.0    NaN
# 观澜    230.0  319.0  1006.0  166.0
# 通心岭    83.0  120.0    77.0    NaN
# 龙岗    103.0  221.0   785.0    NaN

# %%
len(df_cat2)
# Out:
# 13

# %%
sns.set_style('whitegrid', {'font.sans-serif':['simhei', 'Arial']})
ra=pygal.Radar()
ra.title='雷达图'
ra.x_lables=df_cat2.columns
ra.style=Style(froeground_subtle='lightgray')
for i in df_cat2.index:
    ra.add(i,df_cat2.loc[i,:])
ra
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# D:\CODE\Anaconda\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# D:\CODE\Anaconda\lib\site-packages\pygal\graph\base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# D:\CODE\Anaconda\lib\site-packages\pygal\graph\public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
# ...

# %%
# 标准答案
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pygal
from pygal.style import Style

sns.set_style('whitegrid', {'font.sans-serif':['simhei', 'Arial']})
# df = pd.read_excel(r'.\空气监测.xlsx')

df_cat = pd.pivot_table(df, index=['监测点'], columns=['指数级别'], 
                            values='污染指数', aggfunc='sum')

radar_chart = pygal.Radar()
radar_chart.title = '各监测点污染指数'
radar_chart.x_labels = df_cat.columns
radar_chart.style = Style(foreground_subtle='lightgray')
for area in df_cat.index:
    radar_chart.add( area, df_cat.loc[area, :] )
radar_chart
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# D:\CODE\Anaconda\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# D:\CODE\Anaconda\lib\site-packages\pygal\graph\base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# D:\CODE\Anaconda\lib\site-packages\pygal\graph\public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
# ...
